# %%
import collections

import gym
from myutils.gym_custom.gym_custom import MountainCarEnvWrapper
from myutils.trainingClasses.MountainCarConvolutionalTraining import MountainCarConvolutionalTraining

import numpy as np
from myutils.trainingClasses.MountainCarConvolutionalTrainingOfflineLearningWrapper import MountainCarConvolutionalTrainingOfflineLearningWrapper
env = MountainCarEnvWrapper(gym.make('MountainCar-v0').env)

print("Env created")
env.reset()

#agent = MountainCarConvolutionalTraining(env)
agent = MountainCarConvolutionalTrainingOfflineLearningWrapper(env)

print("Started training \n ---------\n")
agent.start()

print("Finished training")

print("minor change for commiting the branch develop-seriously")
# Out:
# Using TensorFlow backend.
# Env created
# Started training
#  ---------
#
# Failed to finish task in episode 0 with reward -300.0 and epsilon 1
# Failed to finish task in episode 1 with reward -300.0 and epsilon 1
# Failed to finish task in episode 2 with reward -300.0 and epsilon 1
# Failed to finish task in episode 3 with reward -300.0 and epsilon 1
# Failed to finish task in episode 4 with reward -300.0 and epsilon 1
# Failed to finish task in episode 5 with reward -300.0 and epsilon 1
# Failed to finish task in episode 6 with reward -300.0 and epsilon 1
# Failed to finish task in episode 7 with reward -300.0 and epsilon 1
# Failed to finish task in episode 8 with reward -300.0 and epsilon 1
# Failed to finish task in episode 9 with reward -300.0 and epsilon 1
# Failed to finish task in episode 10 with reward -300.0 and epsilon 1
# Failed to finish task in episode 11 with reward -300.0 and epsilon 1
# Failed to finish task in episode 12 with reward -300.0 and epsilon 1
# Failed to finish task in episode 13 with reward -300.0 and epsilon 1
# Failed to finish task in episode 14 with reward -300.0 and epsilon 1
# Failed to finish task in episode 15 with reward -300.0 and epsilon 1
# Failed to finish task in episode 16 with reward -300.0 and epsilon 1
# Failed to finish task in episode 17 with reward -300.0 and epsilon 1
# Failed to finish task in episode 18 with reward -300.0 and epsilon 1
# Failed to finish task in episode 19 with reward -300.0 and epsilon 1
# Failed to finish task in episode 20 with reward -300.0 and epsilon 1
# Failed to finish task in episode 21 with reward -300.0 and epsilon 1
# Failed to finish task in episode 22 with reward -300.0 and epsilon 1
# Failed to finish task in episode 23 with reward -300.0 and epsilon 1
# Failed to finish task in episode 24 with reward -300.0 and epsilon 1
# Failed to finish task in episode 25 with reward -300.0 and epsilon 1
# Failed to finish task in episode 26 with reward -300.0 and epsilon 1
# Failed to finish task in episode 27 with reward -300.0 and epsilon 1
# Failed to finish task in episode 28 with reward -300.0 and epsilon 1
# Failed to finish task in episode 29 with reward -300.0 and epsilon 1
# Failed to finish task in episode 30 with reward -300.0 and epsilon 1
# Failed to finish task in episode 31 with reward -300.0 and epsilon 1
# Failed to finish task in episode 32 with reward -300.0 and epsilon 1
# Failed to finish task in episode 33 with reward -300.0 and epsilon 1
# Failed to finish task in episode 34 with reward -300.0 and epsilon 1
# Failed to finish task in episode 35 with reward -300.0 and epsilon 1
# Failed to finish task in episode 36 with reward -300.0 and epsilon 1
# Failed to finish task in episode 37 with reward -300.0 and epsilon 1
# Failed to finish task in episode 38 with reward -300.0 and epsilon 1
# Failed to finish task in episode 39 with reward -300.0 and epsilon 1
# Failed to finish task in episode 40 with reward -300.0 and epsilon 1
# Failed to finish task in episode 41 with reward -300.0 and epsilon 1
# Failed to finish task in episode 42 with reward -300.0 and epsilon 1
# Failed to finish task in episode 43 with reward -300.0 and epsilon 1
# Failed to finish task in episode 44 with reward -300.0 and epsilon 1
# Failed to finish task in episode 45 with reward -300.0 and epsilon 1
# Failed to finish task in episode 46 with reward -300.0 and epsilon 1
# Failed to finish task in episode 47 with reward -300.0 and epsilon 1
# Failed to finish task in episode 48 with reward -300.0 and epsilon 1
# Failed to finish task in episode 49 with reward -300.0 and epsilon 1
# Failed to finish task in episode 50 with reward -300.0 and epsilon 1
# Failed to finish task in episode 51 with reward -300.0 and epsilon 1
# Failed to finish task in episode 52 with reward -300.0 and epsilon 1
# Failed to finish task in episode 53 with reward -300.0 and epsilon 1
# Failed to finish task in episode 54 with reward -300.0 and epsilon 1
# Failed to finish task in episode 55 with reward -300.0 and epsilon 1
# Failed to finish task in episode 56 with reward -300.0 and epsilon 1
# Failed to finish task in episode 57 with reward -300.0 and epsilon 1
# Failed to finish task in episode 58 with reward -300.0 and epsilon 1
# Failed to finish task in episode 59 with reward -300.0 and epsilon 1
# Failed to finish task in episode 60 with reward -300.0 and epsilon 1
# Failed to finish task in episode 61 with reward -300.0 and epsilon 1
# Failed to finish task in episode 62 with reward -300.0 and epsilon 1
# Failed to finish task in episode 63 with reward -300.0 and epsilon 1
# Failed to finish task in episode 64 with reward -300.0 and epsilon 1
# Failed to finish task in episode 65 with reward -300.0 and epsilon 1
# Failed to finish task in episode 66 with reward -300.0 and epsilon 1
# Failed to finish task in episode 67 with reward -300.0 and epsilon 1
# Failed to finish task in episode 68 with reward -300.0 and epsilon 1
# Failed to finish task in episode 69 with reward -300.0 and epsilon 1
# Failed to finish task in episode 70 with reward -300.0 and epsilon 1
# Failed to finish task in episode 71 with reward -300.0 and epsilon 1
# Failed to finish task in episode 72 with reward -300.0 and epsilon 1
# Failed to finish task in episode 73 with reward -300.0 and epsilon 1
# Failed to finish task in episode 74 with reward -300.0 and epsilon 1
# Failed to finish task in episode 75 with reward -300.0 and epsilon 1
# Failed to finish task in episode 76 with reward -300.0 and epsilon 1
# Failed to finish task in episode 77 with reward -300.0 and epsilon 1
# Failed to finish task in episode 78 with reward -300.0 and epsilon 1
# Failed to finish task in episode 79 with reward -300.0 and epsilon 1
# Failed to finish task in episode 80 with reward -300.0 and epsilon 1
# Failed to finish task in episode 81 with reward -300.0 and epsilon 1
# Failed to finish task in episode 82 with reward -300.0 and epsilon 1
# Failed to finish task in episode 83 with reward -300.0 and epsilon 1
# Failed to finish task in episode 84 with reward -300.0 and epsilon 1
# Failed to finish task in episode 85 with reward -300.0 and epsilon 1
# Failed to finish task in episode 86 with reward -300.0 and epsilon 1
# Failed to finish task in episode 87 with reward -300.0 and epsilon 1
# Failed to finish task in episode 88 with reward -300.0 and epsilon 1
# Failed to finish task in episode 89 with reward -300.0 and epsilon 1
# Failed to finish task in episode 90 with reward -300.0 and epsilon 1
# Failed to finish task in episode 91 with reward -300.0 and epsilon 1
# Failed to finish task in episode 92 with reward -300.0 and epsilon 1
# Failed to finish task in episode 93 with reward -300.0 and epsilon 1
# Failed to finish task in episode 94 with reward -300.0 and epsilon 1
# Failed to finish task in episode 95 with reward -300.0 and epsilon 1
# Failed to finish task in episode 96 with reward -300.0 and epsilon 1
# Failed to finish task in episode 97 with reward -300.0 and epsilon 1
# Failed to finish task in episode 98 with reward -300.0 and epsilon 1
# Failed to finish task in episode 99 with reward -300.0 and epsilon 1
# Failed to finish task in episode 100 with reward -300.0 and epsilon 1
# Failed to finish task in episode 101 with reward -300.0 and epsilon 1
# Failed to finish task in episode 102 with reward -300.0 and epsilon 1
# Failed to finish task in episode 103 with reward -300.0 and epsilon 1
# Failed to finish task in episode 104 with reward -300.0 and epsilon 1
# Failed to finish task in episode 105 with reward -300.0 and epsilon 1
# Failed to finish task in episode 106 with reward -300.0 and epsilon 1
# Failed to finish task in episode 107 with reward -300.0 and epsilon 1
# Failed to finish task in episode 108 with reward -300.0 and epsilon 1
# Failed to finish task in episode 109 with reward -300.0 and epsilon 1
# Failed to finish task in episode 110 with reward -300.0 and epsilon 1
# Failed to finish task in episode 111 with reward -300.0 and epsilon 1
# Failed to finish task in episode 112 with reward -300.0 and epsilon 1
# Failed to finish task in episode 113 with reward -300.0 and epsilon 1
# Failed to finish task in episode 114 with reward -300.0 and epsilon 1
# Failed to finish task in episode 115 with reward -300.0 and epsilon 1
# Failed to finish task in episode 116 with reward -300.0 and epsilon 1
# Failed to finish task in episode 117 with reward -300.0 and epsilon 1
# Failed to finish task in episode 118 with reward -300.0 and epsilon 1
# Failed to finish task in episode 119 with reward -300.0 and epsilon 1
# Failed to finish task in episode 120 with reward -300.0 and epsilon 1
# Failed to finish task in episode 121 with reward -300.0 and epsilon 1
# Failed to finish task in episode 122 with reward -300.0 and epsilon 1
# Failed to finish task in episode 123 with reward -300.0 and epsilon 1
# Failed to finish task in episode 124 with reward -300.0 and epsilon 1
# Failed to finish task in episode 125 with reward -300.0 and epsilon 1
# Failed to finish task in episode 126 with reward -300.0 and epsilon 1
# Failed to finish task in episode 127 with reward -300.0 and epsilon 1
# Failed to finish task in episode 128 with reward -300.0 and epsilon 1
# Failed to finish task in episode 129 with reward -300.0 and epsilon 1
# Failed to finish task in episode 130 with reward -300.0 and epsilon 1
# Failed to finish task in episode 131 with reward -300.0 and epsilon 1
# Failed to finish task in episode 132 with reward -300.0 and epsilon 1
# Failed to finish task in episode 133 with reward -300.0 and epsilon 1
# Failed to finish task in episode 134 with reward -300.0 and epsilon 1
# Failed to finish task in episode 135 with reward -300.0 and epsilon 1
# Failed to finish task in episode 136 with reward -300.0 and epsilon 1
# Failed to finish task in episode 137 with reward -300.0 and epsilon 1
# Failed to finish task in episode 138 with reward -300.0 and epsilon 1
# Failed to finish task in episode 139 with reward -300.0 and epsilon 1
# Failed to finish task in episode 140 with reward -300.0 and epsilon 1
# Failed to finish task in episode 141 with reward -300.0 and epsilon 1
# Failed to finish task in episode 142 with reward -300.0 and epsilon 1
# Failed to finish task in episode 143 with reward -300.0 and epsilon 1
# Failed to finish task in episode 144 with reward -300.0 and epsilon 1
# Failed to finish task in episode 145 with reward -300.0 and epsilon 1
# Failed to finish task in episode 146 with reward -300.0 and epsilon 1
# Failed to finish task in episode 147 with reward -300.0 and epsilon 1
# Failed to finish task in episode 148 with reward -300.0 and epsilon 1
# Failed to finish task in episode 149 with reward -300.0 and epsilon 1
# Failed to finish task in episode 150 with reward -300.0 and epsilon 1
# Failed to finish task in episode 151 with reward -300.0 and epsilon 1
# Failed to finish task in episode 152 with reward -300.0 and epsilon 1
# Failed to finish task in episode 153 with reward -300.0 and epsilon 1
# Failed to finish task in episode 154 with reward -300.0 and epsilon 1
# Failed to finish task in episode 155 with reward -300.0 and epsilon 1
# Failed to finish task in episode 156 with reward -300.0 and epsilon 1
# Failed to finish task in episode 157 with reward -300.0 and epsilon 1
# Failed to finish task in episode 158 with reward -300.0 and epsilon 1
# Failed to finish task in episode 159 with reward -300.0 and epsilon 1
# Failed to finish task in episode 160 with reward -300.0 and epsilon 1
# Failed to finish task in episode 161 with reward -300.0 and epsilon 1
# Failed to finish task in episode 162 with reward -300.0 and epsilon 1
# Failed to finish task in episode 163 with reward -300.0 and epsilon 1
# Failed to finish task in episode 164 with reward -300.0 and epsilon 1
# Failed to finish task in episode 165 with reward -300.0 and epsilon 1
# Failed to finish task in episode 166 with reward -300.0 and epsilon 1
# Failed to finish task in episode 167 with reward -300.0 and epsilon 1
# Failed to finish task in episode 168 with reward -300.0 and epsilon 1
# Failed to finish task in episode 169 with reward -300.0 and epsilon 1
# Failed to finish task in episode 170 with reward -300.0 and epsilon 1
# Failed to finish task in episode 171 with reward -300.0 and epsilon 1
# Failed to finish task in episode 172 with reward -300.0 and epsilon 1
# Failed to finish task in episode 173 with reward -300.0 and epsilon 1
# Failed to finish task in episode 174 with reward -300.0 and epsilon 1
# Failed to finish task in episode 175 with reward -300.0 and epsilon 1
# Failed to finish task in episode 176 with reward -300.0 and epsilon 1
# Failed to finish task in episode 177 with reward -300.0 and epsilon 1
# Failed to finish task in episode 178 with reward -300.0 and epsilon 1
# Failed to finish task in episode 179 with reward -300.0 and epsilon 1
# Failed to finish task in episode 180 with reward -300.0 and epsilon 1
# Failed to finish task in episode 181 with reward -300.0 and epsilon 1
# Failed to finish task in episode 182 with reward -300.0 and epsilon 1
# Failed to finish task in episode 183 with reward -300.0 and epsilon 1
# Failed to finish task in episode 184 with reward -300.0 and epsilon 1
# Failed to finish task in episode 185 with reward -300.0 and epsilon 1
# Failed to finish task in episode 186 with reward -300.0 and epsilon 1
# Failed to finish task in episode 187 with reward -300.0 and epsilon 1
# Failed to finish task in episode 188 with reward -300.0 and epsilon 1
# Failed to finish task in episode 189 with reward -300.0 and epsilon 1
# Failed to finish task in episode 190 with reward -300.0 and epsilon 1
# Failed to finish task in episode 191 with reward -300.0 and epsilon 1
# Failed to finish task in episode 192 with reward -300.0 and epsilon 1
# Failed to finish task in episode 193 with reward -300.0 and epsilon 1
# Failed to finish task in episode 194 with reward -300.0 and epsilon 1
# Failed to finish task in episode 195 with reward -300.0 and epsilon 1
# Failed to finish task in episode 196 with reward -300.0 and epsilon 1
# Failed to finish task in episode 197 with reward -300.0 and epsilon 1
# Failed to finish task in episode 198 with reward -300.0 and epsilon 1
# Failed to finish task in episode 199 with reward -300.0 and epsilon 1
# Failed to finish task in episode 200 with reward -300.0 and epsilon 1
# Failed to finish task in episode 201 with reward -300.0 and epsilon 1
# Failed to finish task in episode 202 with reward -300.0 and epsilon 1
# Failed to finish task in episode 203 with reward -300.0 and epsilon 1
# Failed to finish task in episode 204 with reward -300.0 and epsilon 1
# Failed to finish task in episode 205 with reward -300.0 and epsilon 1
# Failed to finish task in episode 206 with reward -300.0 and epsilon 1
# Failed to finish task in episode 207 with reward -300.0 and epsilon 1
# Failed to finish task in episode 208 with reward -300.0 and epsilon 1
# Failed to finish task in episode 209 with reward -300.0 and epsilon 1
# Failed to finish task in episode 210 with reward -300.0 and epsilon 1
# Failed to finish task in episode 211 with reward -300.0 and epsilon 1
# Failed to finish task in episode 212 with reward -300.0 and epsilon 1
# Failed to finish task in episode 213 with reward -300.0 and epsilon 1
# Failed to finish task in episode 214 with reward -300.0 and epsilon 1
# Failed to finish task in episode 215 with reward -300.0 and epsilon 1
# Failed to finish task in episode 216 with reward -300.0 and epsilon 1
# Failed to finish task in episode 217 with reward -300.0 and epsilon 1
# Failed to finish task in episode 218 with reward -300.0 and epsilon 1
# Failed to finish task in episode 219 with reward -300.0 and epsilon 1
# Failed to finish task in episode 220 with reward -300.0 and epsilon 1
# Failed to finish task in episode 221 with reward -300.0 and epsilon 1
# Failed to finish task in episode 222 with reward -300.0 and epsilon 1
# Failed to finish task in episode 223 with reward -300.0 and epsilon 1
# Failed to finish task in episode 224 with reward -300.0 and epsilon 1
# Failed to finish task in episode 225 with reward -300.0 and epsilon 1
# Failed to finish task in episode 226 with reward -300.0 and epsilon 1
# Failed to finish task in episode 227 with reward -300.0 and epsilon 1
# Failed to finish task in episode 228 with reward -300.0 and epsilon 1
# Failed to finish task in episode 229 with reward -300.0 and epsilon 1
# Failed to finish task in episode 230 with reward -300.0 and epsilon 1
# Failed to finish task in episode 231 with reward -300.0 and epsilon 1
# Failed to finish task in episode 232 with reward -300.0 and epsilon 1
# Failed to finish task in episode 233 with reward -300.0 and epsilon 1
# Failed to finish task in episode 234 with reward -300.0 and epsilon 1
# Failed to finish task in episode 235 with reward -300.0 and epsilon 1
# Failed to finish task in episode 236 with reward -300.0 and epsilon 1
# Failed to finish task in episode 237 with reward -300.0 and epsilon 1
# Failed to finish task in episode 238 with reward -300.0 and epsilon 1
# Failed to finish task in episode 239 with reward -300.0 and epsilon 1
# Failed to finish task in episode 240 with reward -300.0 and epsilon 1
# Failed to finish task in episode 241 with reward -300.0 and epsilon 1
# Failed to finish task in episode 242 with reward -300.0 and epsilon 1
# Failed to finish task in episode 243 with reward -300.0 and epsilon 1
# Failed to finish task in episode 244 with reward -300.0 and epsilon 1
# Failed to finish task in episode 245 with reward -300.0 and epsilon 1
# Failed to finish task in episode 246 with reward -300.0 and epsilon 1
# Failed to finish task in episode 247 with reward -300.0 and epsilon 1
# Failed to finish task in episode 248 with reward -300.0 and epsilon 1
# Failed to finish task in episode 249 with reward -300.0 and epsilon 1
# Failed to finish task in episode 250 with reward -300.0 and epsilon 1
# Failed to finish task in episode 251 with reward -300.0 and epsilon 1
# Failed to finish task in episode 252 with reward -300.0 and epsilon 1
# Failed to finish task in episode 253 with reward -300.0 and epsilon 1
# Failed to finish task in episode 254 with reward -300.0 and epsilon 1
# Failed to finish task in episode 255 with reward -300.0 and epsilon 1
# Failed to finish task in episode 256 with reward -300.0 and epsilon 1
# Failed to finish task in episode 257 with reward -300.0 and epsilon 1
# Failed to finish task in episode 258 with reward -300.0 and epsilon 1
# Failed to finish task in episode 259 with reward -300.0 and epsilon 1
# Failed to finish task in episode 260 with reward -300.0 and epsilon 1
# Failed to finish task in episode 261 with reward -300.0 and epsilon 1
# Failed to finish task in episode 262 with reward -300.0 and epsilon 1
# Failed to finish task in episode 263 with reward -300.0 and epsilon 1
# Failed to finish task in episode 264 with reward -300.0 and epsilon 1
# Failed to finish task in episode 265 with reward -300.0 and epsilon 1
# Failed to finish task in episode 266 with reward -300.0 and epsilon 1
# Failed to finish task in episode 267 with reward -300.0 and epsilon 1
# Failed to finish task in episode 268 with reward -300.0 and epsilon 1
# Failed to finish task in episode 269 with reward -300.0 and epsilon 1
# Failed to finish task in episode 270 with reward -300.0 and epsilon 1
# Failed to finish task in episode 271 with reward -300.0 and epsilon 1
# Failed to finish task in episode 272 with reward -300.0 and epsilon 1
# Failed to finish task in episode 273 with reward -300.0 and epsilon 1
# Failed to finish task in episode 274 with reward -300.0 and epsilon 1
# Failed to finish task in episode 275 with reward -300.0 and epsilon 1
# Failed to finish task in episode 276 with reward -300.0 and epsilon 1
# Failed to finish task in episode 277 with reward -300.0 and epsilon 1
# Failed to finish task in episode 278 with reward -300.0 and epsilon 1
# Failed to finish task in episode 279 with reward -300.0 and epsilon 1
# Failed to finish task in episode 280 with reward -300.0 and epsilon 1
# Failed to finish task in episode 281 with reward -300.0 and epsilon 1
# Failed to finish task in episode 282 with reward -300.0 and epsilon 1
# Failed to finish task in episode 283 with reward -300.0 and epsilon 1
# Failed to finish task in episode 284 with reward -300.0 and epsilon 1
# Failed to finish task in episode 285 with reward -300.0 and epsilon 1
# Failed to finish task in episode 286 with reward -300.0 and epsilon 1
# Failed to finish task in episode 287 with reward -300.0 and epsilon 1
# Failed to finish task in episode 288 with reward -300.0 and epsilon 1
# Failed to finish task in episode 289 with reward -300.0 and epsilon 1
# Failed to finish task in episode 290 with reward -300.0 and epsilon 1
# Failed to finish task in episode 291 with reward -300.0 and epsilon 1
# Failed to finish task in episode 292 with reward -300.0 and epsilon 1
# Failed to finish task in episode 293 with reward -300.0 and epsilon 1
# Failed to finish task in episode 294 with reward -300.0 and epsilon 1
# Failed to finish task in episode 295 with reward -300.0 and epsilon 1
# Failed to finish task in episode 296 with reward -300.0 and epsilon 1
# Failed to finish task in episode 297 with reward -300.0 and epsilon 1
# Failed to finish task in episode 298 with reward -300.0 and epsilon 1
# Failed to finish task in episode 299 with reward -300.0 and epsilon 1
# Failed to finish task in episode 300 with reward -300.0 and epsilon 1
# Failed to finish task in episode 301 with reward -300.0 and epsilon 1
# Failed to finish task in episode 302 with reward -300.0 and epsilon 1
# Failed to finish task in episode 303 with reward -300.0 and epsilon 1
# Failed to finish task in episode 304 with reward -300.0 and epsilon 1
# Failed to finish task in episode 305 with reward -300.0 and epsilon 1
# Failed to finish task in episode 306 with reward -300.0 and epsilon 1
# Failed to finish task in episode 307 with reward -300.0 and epsilon 1
# Failed to finish task in episode 308 with reward -300.0 and epsilon 1
# Failed to finish task in episode 309 with reward -300.0 and epsilon 1
# Failed to finish task in episode 310 with reward -300.0 and epsilon 1
# Failed to finish task in episode 311 with reward -300.0 and epsilon 1
# Failed to finish task in episode 312 with reward -300.0 and epsilon 1
# Failed to finish task in episode 313 with reward -300.0 and epsilon 1
# Failed to finish task in episode 314 with reward -300.0 and epsilon 1
# Failed to finish task in episode 315 with reward -300.0 and epsilon 1
# Failed to finish task in episode 316 with reward -300.0 and epsilon 1
# Failed to finish task in episode 317 with reward -300.0 and epsilon 1
# Failed to finish task in episode 318 with reward -300.0 and epsilon 1
# Failed to finish task in episode 319 with reward -300.0 and epsilon 1
# Failed to finish task in episode 320 with reward -300.0 and epsilon 1
# Failed to finish task in episode 321 with reward -300.0 and epsilon 1
# Failed to finish task in episode 322 with reward -300.0 and epsilon 1
# Failed to finish task in episode 323 with reward -300.0 and epsilon 1
# Failed to finish task in episode 324 with reward -300.0 and epsilon 1
# Failed to finish task in episode 325 with reward -300.0 and epsilon 1
# Failed to finish task in episode 326 with reward -300.0 and epsilon 1
# Failed to finish task in episode 327 with reward -300.0 and epsilon 1
# Failed to finish task in episode 328 with reward -300.0 and epsilon 1
# Failed to finish task in episode 329 with reward -300.0 and epsilon 1
# Failed to finish task in episode 330 with reward -300.0 and epsilon 1
# Failed to finish task in episode 331 with reward -300.0 and epsilon 1
# Failed to finish task in episode 332 with reward -300.0 and epsilon 1
# Failed to finish task in episode 333 with reward -300.0 and epsilon 1
# Failed to finish task in episode 334 with reward -300.0 and epsilon 1
# Failed to finish task in episode 335 with reward -300.0 and epsilon 1
# Failed to finish task in episode 336 with reward -300.0 and epsilon 1
# Failed to finish task in episode 337 with reward -300.0 and epsilon 1
# Failed to finish task in episode 338 with reward -300.0 and epsilon 1
# Failed to finish task in episode 339 with reward -300.0 and epsilon 1
# Failed to finish task in episode 340 with reward -300.0 and epsilon 1
# Success in epsoide 341, used 251 time steps!
# Failed to finish task in episode 342 with reward -300.0 and epsilon 1
# Failed to finish task in episode 343 with reward -300.0 and epsilon 1
# Failed to finish task in episode 344 with reward -300.0 and epsilon 1
# Failed to finish task in episode 345 with reward -300.0 and epsilon 1
# Failed to finish task in episode 346 with reward -300.0 and epsilon 1
# Failed to finish task in episode 347 with reward -300.0 and epsilon 1
# Failed to finish task in episode 348 with reward -300.0 and epsilon 1
# Failed to finish task in episode 349 with reward -300.0 and epsilon 1
# Failed to finish task in episode 350 with reward -300.0 and epsilon 1
# Failed to finish task in episode 351 with reward -300.0 and epsilon 1
# Failed to finish task in episode 352 with reward -300.0 and epsilon 1
# Failed to finish task in episode 353 with reward -300.0 and epsilon 1
# Failed to finish task in episode 354 with reward -300.0 and epsilon 1
# Failed to finish task in episode 355 with reward -300.0 and epsilon 1
# Failed to finish task in episode 356 with reward -300.0 and epsilon 1
# Failed to finish task in episode 357 with reward -300.0 and epsilon 1
# Failed to finish task in episode 358 with reward -300.0 and epsilon 1
# Failed to finish task in episode 359 with reward -300.0 and epsilon 1
# Failed to finish task in episode 360 with reward -300.0 and epsilon 1
# Failed to finish task in episode 361 with reward -300.0 and epsilon 1
# Failed to finish task in episode 362 with reward -300.0 and epsilon 1
# Failed to finish task in episode 363 with reward -300.0 and epsilon 1
# Failed to finish task in episode 364 with reward -300.0 and epsilon 1
# Failed to finish task in episode 365 with reward -300.0 and epsilon 1
# Failed to finish task in episode 366 with reward -300.0 and epsilon 1
# Failed to finish task in episode 367 with reward -300.0 and epsilon 1
# Failed to finish task in episode 368 with reward -300.0 and epsilon 1
# Failed to finish task in episode 369 with reward -300.0 and epsilon 1
# Failed to finish task in episode 370 with reward -300.0 and epsilon 1
# Failed to finish task in episode 371 with reward -300.0 and epsilon 1
# Failed to finish task in episode 372 with reward -300.0 and epsilon 1
# Failed to finish task in episode 373 with reward -300.0 and epsilon 1
# Failed to finish task in episode 374 with reward -300.0 and epsilon 1
# Failed to finish task in episode 375 with reward -300.0 and epsilon 1
# Failed to finish task in episode 376 with reward -300.0 and epsilon 1
# Failed to finish task in episode 377 with reward -300.0 and epsilon 1
# Failed to finish task in episode 378 with reward -300.0 and epsilon 1
# Failed to finish task in episode 379 with reward -300.0 and epsilon 1
# Failed to finish task in episode 380 with reward -300.0 and epsilon 1
# Failed to finish task in episode 381 with reward -300.0 and epsilon 1
# Failed to finish task in episode 382 with reward -300.0 and epsilon 1
# Failed to finish task in episode 383 with reward -300.0 and epsilon 1
# Failed to finish task in episode 384 with reward -300.0 and epsilon 1
# Failed to finish task in episode 385 with reward -300.0 and epsilon 1
# Failed to finish task in episode 386 with reward -300.0 and epsilon 1
# Failed to finish task in episode 387 with reward -300.0 and epsilon 1
# Failed to finish task in episode 388 with reward -300.0 and epsilon 1
# Failed to finish task in episode 389 with reward -300.0 and epsilon 1
# Failed to finish task in episode 390 with reward -300.0 and epsilon 1
# Failed to finish task in episode 391 with reward -300.0 and epsilon 1
# Failed to finish task in episode 392 with reward -300.0 and epsilon 1
# Failed to finish task in episode 393 with reward -300.0 and epsilon 1
# Failed to finish task in episode 394 with reward -300.0 and epsilon 1
# Failed to finish task in episode 395 with reward -300.0 and epsilon 1
# Failed to finish task in episode 396 with reward -300.0 and epsilon 1

# %%
import collections
import pickle
import gym
from myutils.trainingClasses.MountainCarTrain import MountainCarTrain

import numpy as np


env = gym.make('MountainCar-v0')

print("AAA")
env.reset()
print(env.render(mode='rgb_array').shape)
print(env.action_space.contains(3))
agent = MountainCarTrain(env)
agent.start()

print("Yahoo")
# Out:
# AAA
# (400, 600, 3)
# False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-29c682b65f6f> in <module>
#      15 print(env.action_space.contains(3))
#      16 agent = MountainCarTrain(env)
# ---> 17 agent.start()
#      18
#      19 print("Yahoo")
#
# E:\licenta\code\DQN\FuzzyPartition\myutils\trainingClasses\MountainCarTrain.py in start(self)
#     166         for eps in range(self.episodeNum):
#     167             currentState = self.env.reset().reshape(1, 2)
# --> 168             self.orginalTry(currentState, eps)
#
# E:\licenta\code\DQN\FuzzyPartition\myutils\trainingClasses\MountainCarTrain.py in orginalTry(self, currentState, eps)
#     137
#     138             # Or you can use self.trainFromBuffer_Boost(), it is a matrix wise version for boosting
# --> 139             self.trainFromBuffer()
#     140
#     141             rewardSum += reward
#
# E:\licenta\code\DQN\FuzzyPartition\myutils\trainingClasses\MountainCarTrain.py in trainFromBuffer(self)
#      98         newStates = newArray2.reshape(self.numPickFromBuffer, 2)
#      99
# --> 100         targets = self.trainNetwork.predict(states)
#     101         new_state_targets = self.targetNetwork.predict(newStates)
#     102
#
# ~\Miniconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# ~\Miniconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# ~\Miniconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~\Miniconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~\Miniconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~\Miniconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~\Miniconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~\Miniconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
